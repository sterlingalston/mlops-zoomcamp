# %% [markdown]
# Q1. Select the Tool
#
# What's the name of the orchestrator you choose?
#
# *I choose to use [Apache Nifi](https://nifi.apache.org/)  I have worked with this for my Data Engineering projects.*
#
# ![Screenshot](nifi-screen.png)

# %% [markdown]
# Q2. Version
#
# What's the version of the orachestrator?
#
# *The version I'm on is Nifi 2.4.0*
#
# ![Version](nifi-version.png)

# %% [markdown]
# Q3. How many records did we load?
#
# 3,003,722\
# 3,203,766\
# **3,403,766**\
# 3,603,766

# %% [markdown]
# Q4. What's the size of the result?
#
# 2,903,766\
# 3,103,766\
# **3,316,216**\
# 3,503,766

# %% [markdown]
# Q5. What's the intercept of the model?
#
# 21.77\
# 24.77\
# **27.77**\
# 31.77

# %% [markdown]
# Q6. What's the size of the model?
#
# **14,534**\
# 9,534\
# 4,534\
# 1,534
